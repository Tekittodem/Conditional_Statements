# %% [markdown]
# <a href="https://colab.research.google.com/github/Tekittodem/Conditional_Statements/blob/master/Deliverable_(9).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
iris = pd.read_csv('iris.csv')  
iris.head()
# Out:
#    Unnamed: 0  sepal length (cm)  sepal width (cm)  petal length (cm)  \
# 0           0                5.1               3.5                1.4
# 1           1                4.9               3.0                1.4
# 2           2                4.7               3.2                1.3
# 3           3                4.6               3.1                1.5
# 4           4                5.0               3.6                1.4
#
#    petal width (cm)  target
# 0               0.2       0
# 1               0.2       0
# 2               0.2       0
# 3               0.2       0
# 4               0.2       0

# %%
# Split the data into features (X) and response (y)

# %%
cols = iris.columns[1:]
iris = iris[cols]
iris.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
features = iris.columns[:-1]
X = iris[features]
Y = iris['target']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(random_state=0)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
predictions = classifier.predict(X_test)
iris_pred = pd.DataFrame({'Actual': y_test, 'Predictions': predictions})
iris_pred.head()
# Out:
#      Actual  Predictions
# 114       2            2
# 62        1            1
# 33        0            0
# 107       2            2
# 7         0            0

# %%
from sklearn.metrics import accuracy_score
print('Accuracy score on test data: ', accuracy_score(y_test, predictions))
# Out:
# Accuracy score on test data:  0.9736842105263158

# %%
from sklearn.metrics import confusion_matrix
idx = ['actual 0', 'actual 1', 'actual 2']

cm = pd.DataFrame(confusion_matrix(y_test, predictions),
                  columns = ['pred 0', 'pred 1', 'pred 2'],
                  index= idx)
cm
# Out:
#           pred 0  pred 1  pred 2
# actual 0      13       0       0
# actual 1       0      15       1
# actual 2       0       0       9
